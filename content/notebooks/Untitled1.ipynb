# %%
import pymc3 as pm
from pymc3.glm import glm
import numpy as np
import pandas as pd
import datetime
import scipy.stats

from scipy import optimize
import theano as thno
import theano.tensor as T

# data retrieval helper module
from general.DB import DB
import util

from sklearn.linear_model import LinearRegression

# plotting libraries
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import seaborn as sns
# %matplotlib inline

# %%
# get the data we need from the database
year = 2015
games_df, stacked, teams = util.get_data(year)
games_df = games_df.sort('dt')  # sort by date ascending
kenpom = pd.read_sql("SELECT team, adjt FROM kenpom_ranks WHERE year = %s" % year, DB.conn)
all_teams = pd.read_sql("SELECT ncaa, ncaaid, kenpom FROM teams", DB.conn)
teams = teams.merge(all_teams, left_on='team_id', right_on='ncaaid')
teams = teams.merge(kenpom, how='left', left_on='kenpom', right_on='team').drop(['team', 'kenpom', 'ncaaid'], 1)
num_teams = teams.shape[0]
print("Got data for %s games and %s teams, between %s and %s" % (games_df.shape[0], num_teams,
                                                   datetime.datetime.strftime(games_df['dt'].min(), "%m-%d-%Y"),
                                                  datetime.datetime.strftime(games_df['dt'].max(), "%m-%d-%Y")))
# Out:
# Got data for 5279 games and 351 teams, between 11-16-2014 and 04-06-2015

# %%
stacked.shape
# Out:
# (10558, 20)

# %%
def get_indices(unstacked, approx_burn_games, approx_interval):
    date_counts = unstacked.groupby('dt').count()['game_id']
    cum_indices = np.cumsum(date_counts).values
    next_ = cum_indices[-1]
    indices = []
    for gp in cum_indices[::-1]:
        if gp <= approx_burn_games:
            break
        if gp <= next_:
            indices.append(gp)
            next_ -= approx_interval
    return indices[::-1]

def get_points_matrix(home_idx, away_idx, home_ppp, away_ppp, is_neutral, is_log=False):
    home_off_mat = pd.get_dummies(home_idx, prefix='o')
    away_def_mat = pd.get_dummies(away_idx, prefix='d')
    df1 = pd.concat([home_off_mat, away_def_mat], axis=1)
    df1['ppp'] = home_ppp if not is_log else np.log(home_ppp)
    df1['home'] = (~is_neutral).astype(int)

    home_def_mat = pd.get_dummies(home_idx, prefix='d')
    away_off_mat = pd.get_dummies(away_idx, prefix='o')
    df2 = pd.concat([away_off_mat, home_def_mat], axis=1)
    df2['ppp'] = away_ppp if not is_log else np.log(away_ppp)
    df2['home'] = is_neutral.astype(int) - 1.0

    df = pd.concat([df1, df2], axis=0).sort_index()
    predictors = ['o_%s' % i for i in range(num_teams - 1)] + ['d_%s' % i for i in range(num_teams - 1)] + ['home']
    X = df[predictors].values
    y = df['ppp'].values
    return X, y

def extract_coef(lr, num_teams):
    o = np.zeros(num_teams)
    o[:-1] = lr.coef_[:num_teams - 1]
    d = np.zeros(num_teams)
    d[:-1] = lr.coef_[num_teams - 1:2 * num_teams - 2]
    return o, d

# %%
def get_temporal_weights(N, weight_type="exponential"):
    weights = np.ones(2*N)
    if weight_type == "exponential":
        memory = 1000
        if N < memory:
            return weights
        else:
            idx = np.arange(N - memory)*2
            weights[idx] = np.exp(np.arange(-(N - memory), 0) / 500.)
            weights[idx + 1] = np.exp(np.arange(-(N - memory), 0) / 500.)
    elif weight_type == "window":
        window_len = 3000
        if N < window_len:
            return weights
        else:
            weights[:window_len*2] = 0
    else:
        pass
    
    return weights

def get_mov_weights(pred_diffs, diffs):
    mov = np.array([mov_weights(p, d) for p, d in zip(pred_diffs, diffs)])
    weights = np.zeros(pred_diffs.shape[0] *2)
    idx = np.arange(pred_diffs.shape[0]) * 2
    weights[idx] = mov
    weights[idx + 1] = mov
    return weights

def get_poss_weights(poss, N):
    weights = np.zeros(2 * N)
    idx = np.arange(N) * 2
    weights[idx] = 1 / poss[:N]
    weights[idx + 1] = 1 / poss[:N]
    return weights

def mov_weights(pred_diff, diff):
    if pred_diff > 0.2 and diff > 0.2:
        # home expected big win and was big win
        weight = 0.2
    elif pred_diff > 0.2 and diff < 0:
        # home expected big win and was loss
        weight = 2
    elif pred_diff < -0.2 and diff < -0.2:
        # away win big and away won big
        weight = 0.2
    elif pred_diff < -0.2 and diff > 0:
        # away expected win big and lost
        weight = 2
    else:
        weight = 1
    return weight
    
def rate_for_season(season_data, skip_interval=100, temporal_weights="all", is_log=False, verbose=False):
    X, y = get_points_matrix(season_data['i_hteam'].values, season_data['i_ateam'].values, season_data['hppp'].values, 
        season_data['appp'].values, season_data['neutral'].values, is_log=is_log)
    
    # fit all the data initially to get the home_factor
    zero_lr = LinearRegression()
    zero_lr.fit(X, y)
    home_factor = zero_lr.coef_[-1]
    if verbose:
        print("Home factor for %s season is %1.3f points per possession" % (year, home_factor))
    home_adjustment = X[:, -1] * home_factor * -1

    all_home_indices = season_data['i_hteam'].values
    all_away_indices = season_data['i_ateam'].values
    all_home_off_ratings = np.ones(season_data.shape[0]) * -1
    all_home_def_ratings = np.ones(season_data.shape[0]) * -1
    all_away_off_ratings = np.ones(season_data.shape[0]) * -1
    all_away_def_ratings = np.ones(season_data.shape[0]) * -1
    all_intercepts = np.ones(season_data.shape[0]) * -1
    
    indices = get_indices(games_df, 1000, skip_interval)
    prev_idx = indices[0]
    _lr = LinearRegression()
    for i, idx in enumerate(indices[1:]):
        hppp_pred = all_home_off_ratings[:prev_idx] + all_away_def_ratings[:prev_idx] + home_factor + \
            all_intercepts[:prev_idx]
        appp_pred = all_away_off_ratings[:prev_idx] + all_home_def_ratings[:prev_idx] - home_factor + \
            all_intercepts[:prev_idx]
        ppp_diff_pred = hppp_pred - appp_pred
        ppp_diff = (season_data['hppp'] - season_data['appp']).values[:prev_idx]
        mov_weights = get_mov_weights(ppp_diff_pred, ppp_diff)
        _X = X[:prev_idx * 2, :-1]
        _y = y[:prev_idx * 2] + home_adjustment[:prev_idx * 2]
        _lr.fit(_X, _y, sample_weight=get_poss_weights(season_data['poss'].values, prev_idx))
        if i % 10 == 0 and verbose:
            print("Iteration %s: fit linear regression on %s rows and %s columns" % (i, _X.shape[0], _X.shape[1]))
        ortg, drtg = extract_coef(_lr, num_teams)

        _home_indices = all_home_indices[prev_idx:idx]
        _away_indices = all_away_indices[prev_idx:idx]
        all_home_off_ratings[prev_idx:idx] = ortg[_home_indices]
        all_away_off_ratings[prev_idx:idx] = ortg[_away_indices]
        all_home_def_ratings[prev_idx:idx] = drtg[_home_indices]
        all_away_def_ratings[prev_idx:idx] = drtg[_away_indices]
        all_intercepts[prev_idx:idx] = _lr.intercept_
        prev_idx = idx
    return {'hortg': all_home_off_ratings, 'hdrtg': all_home_def_ratings,
            'aortg': all_away_off_ratings, 'adrtg': all_away_def_ratings, 
            'intercept': all_intercepts}, home_factor

# %%
def add_ratings(df, ratings, home_factor):
    for col, rtg in ratings.items():
        df[col] = rtg
    df['month'] = df['dt'].map(lambda dt: dt.month)
    df['hpred'] = (df['hortg'] + df['adrtg'] + home_factor * ~df['neutral'] + df['intercept']).values
    df['apred'] = (df['aortg'] + df['hdrtg'] - home_factor * ~df['neutral'] + df['intercept']).values
    df['outcome_pred'] = df['hpred'] > df['apred']
    df['correct'] = df['outcome_pred'] == df['home_outcome']
    return df[df['hortg'] != -1.]

# %%
relevant_cols = ['dt', 'hteam', 'ateam', 'hppp', 'appp', 'neutral', 'home_outcome']
ratings, home_factor = rate_for_season(games_df, skip_interval=100, temporal_weights="all", is_log=False)
df0 = add_ratings(games_df[relevant_cols].copy(), ratings, home_factor)
# Out:
# /usr/local/lib/python3.4/site-packages/scipy/linalg/basic.py:884: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   warnings.warn(mesg, RuntimeWarning)

# %%
games_df.head()
# Out:
#       game_id          dt          hteam  hteam_id          ateam  ateam_id  \
# 4030  3509779  2014-11-16     Miami (OH)     414.0  Southern Utah     667.0
# 2617  3512375  2014-11-16  East Carolina     196.0  UNC Asheville     456.0
# 3375  3512373  2014-11-16            UCF     128.0        Stetson     678.0
# 3419  3510544  2014-11-16     Seton Hall     635.0         Mercer     406.0
# 847   3512441  2014-11-16       Virginia     746.0    Norfolk St.     485.0
#
#       hpts   hposs  apts   aposs  i_hteam  i_ateam      hppp      appp  \
# 4030    76  71.150    63  67.500      156      268  1.068166  0.933333
# 2617    79  77.250    83  76.150       77      173  1.022654  1.089954
# 3375    64  62.825    55  64.125       49      274  1.018703  0.857700
# 3419    63  65.025    47  63.750      252      155  0.968858  0.737255
# 847     67  58.075    39  56.275      308      189  1.153681  0.693025
#
#      neutral home_outcome     poss  season
# 4030   False         True  69.3250    2015
# 2617   False        False  76.7000    2015
# 3375   False         True  63.4750    2015
# 3419   False         True  64.3875    2015
# 847    False         True  57.1750    2015

# %%
print(df0[df0['month'] != 11]['correct'].mean())
pd.merge(df0.groupby('month').mean()[['correct']], df0.groupby('month').count()[['correct']], 
         left_index=True, right_index=True)
# Out:
# 0.715472235406
#        correct_x  correct_y
# month
# 1       0.717812       1499
# 2       0.703331       1291
# 3       0.717156        647
# 4       0.666667          6
# 12      0.730220        771

# %%
ratings, home_factor = rate_for_season(games_df, skip_interval=300, verbose=True)
df1 = add_ratings(games_df[relevant_cols].copy(), ratings, home_factor)
# Out:
# Home factor for 2016 season is 0.023 points per possession
# Iteration 0: fit linear regression on 2474 rows and 700 columns
# Iteration 10: fit linear regression on 8470 rows and 700 columns

# %%
ratings, home_factor = rate_for_season(games_df, skip_interval=300, is_log=True, temporal_weights=True, verbose=True)
df2 = add_ratings(games_df[relevant_cols].copy(), ratings, home_factor)
# Out:
# Home factor for 2016 season is 0.022 points per possession
# Iteration 0: fit linear regression on 2474 rows and 700 columns
# Iteration 10: fit linear regression on 8470 rows and 700 columns

# %%
ratings, home_factor = rate_for_season(games_df, skip_interval=300, temporal_weights=True, verbose=True)
df3 = add_ratings(games_df[relevant_cols].copy(), ratings, home_factor)
# Out:
# Home factor for 2016 season is 0.023 points per possession
# Iteration 0: fit linear regression on 2474 rows and 700 columns
# Iteration 10: fit linear regression on 8470 rows and 700 columns

# %%
print(df1['correct'].mean())
pd.merge(df1.groupby('month').mean()[['correct']], df1.groupby('month').count()[['correct']], 
         left_index=True, right_index=True)
# Out:
# 0.711457378552
#        correct_x  correct_y
# month
# 1       0.699243       1453
# 2       0.707317       1353
# 3       0.717460        630
# 4       0.500000          4
# 11      0.686084        927
# 12      0.751838       1088

# %%
df0.shape
# Out:
# (5455, 17)

# %%
kp = pd.read_sql("SELECT * FROM kp", DB.conn)

# %%
kp['month'] = kp['dt'].map(lambda dt: dt.month)
kp['season'] = kp['dt'].map(lambda dt: dt.year if dt.month < 6 else dt.year + 1)
kp['outcome'] = kp['score1'] > kp['score2']
kp['pred_outcome'] = kp['predicted_score'] > kp['predicted_score2']
kp['mov'] = kp['score1'] - kp['score2']
kp['correct'] = kp['team1'] == kp['predicted']
kp = kp[kp['month'] != 11]
kp_gb = kp.groupby(['month', 'season']).mean()[['correct', 'mov']]

# %%
print(kp[kp['season'] == 2015]['correct'].mean())
kp_gb
# Out:
# 0.722027972028
#                correct        mov
# month season
# 1     2011    0.721831  11.194366
#       2012    0.726096  11.148814
#       2013    0.712446  11.196710
#       2014    0.683140  10.797238
#       2015    0.714286  10.457672
# 2     2011    0.716144  10.319816
#       2012    0.749451  10.653480
#       2013    0.715962  11.008607
#       2014    0.735994  10.425173
#       2015    0.703280  10.756674
# 3     2011    0.717428  10.807107
#       2012    0.718147  10.415058
#       2013    0.712975  10.560944
#       2014    0.716456  10.554430
#       2015    0.718894   9.927803
# 4     2011    0.750000   5.750000
#       2012    1.000000   8.000000
#       2013    0.700000   7.300000
#       2014    0.363636   9.000000
#       2015    0.500000   6.833333
# 12    2011    0.803366  13.007972
#       2012    0.793345  13.385289
#       2013    0.797862  13.693878
#       2014    0.767196  13.041270
#       2015    0.758212  12.989964

# %%
sub = games_df[~games_df['neutral']].copy()
sub['month'] = sub['dt'].map(lambda d: d.month)
sub.groupby('month').mean()[['home_outcome']]
# Out:
#        home_outcome
# month
# 1          0.585114
# 2          0.623521
# 3          0.631922
# 4          0.500000
# 11         0.765130
# 12         0.715407

# %%
kp
# Out:
#                dt             team1  score1                  team2  score2  \
# 0      2010-11-08        Pittsburgh      83           Rhode Island      75
# 1      2010-11-08          Illinois      79              UC Irvine      65
# 2      2010-11-08          Maryland     105                Seattle      76
# 3      2010-11-08             Texas      83                   Navy      52
# 4      2010-11-10          Maryland      75  College of Charleston      74
# 5      2010-11-10        Pittsburgh      97       Illinois Chicago      54
# 6      2010-11-10             Texas      89         Louisiana Tech      58
# 7      2010-11-10          Illinois      84                 Toledo      45
# 8      2010-11-12        Georgetown      62           Old Dominion      59
# 9      2010-11-12            Temple      62             Seton Hall      56
# 10     2010-11-12     Southern Miss      60          South Florida      53
# 11     2010-11-12          Kent St.      73                   Iona      72
# 12     2010-11-12         Minnesota      69                Wofford      55
# 13     2010-11-12  Western Kentucky      98         Saint Joseph's      70
# 14     2010-11-12      Missouri St.      78           Oral Roberts      61
# 15     2010-11-12           Pacific      66                   UTEP      61
# 16     2010-11-12      Northeastern      66      Boston University      64
# 17     2010-11-12   Appalachian St.      89                  Tulsa      86
# 18     2010-11-12          Kentucky      88     East Tennessee St.      65
# 19     2010-11-12          Syracuse      68          Northern Iowa      46
# 20     2010-11-12            Drexel      75              Loyola MD      72
# 21     2010-11-12     Massachusetts      77                  Rider      67
# 22     2010-11-12         Princeton      78                Rutgers      73
# 23     2010-11-12          Canisius      80        St. Bonaventure      70
# 24     2010-11-12  UC Santa Barbara      65                 Denver      49
# 25     2010-11-12    Loyola Chicago      73       Eastern Kentucky      57
# 26     2010-11-12  Florida Atlantic      70               UC Davis      63
# 27     2010-11-12          Iowa St.      78       Northern Arizona      64
# 28     2010-11-12      Portland St.      83             Pepperdine      81
# 29     2010-11-12    North Carolina      80               Lipscomb      66
# ...           ...               ...     ...                    ...     ...
# 27226  2015-03-25            Temple      77         Louisiana Tech      59
# 27227  2015-03-25  Louisiana Monroe      71                Vermont      65
# 27228  2015-03-25  Tennessee Martin      70       Eastern Kentucky      69
# 27229  2015-03-25    Loyola Chicago      63                Seattle      48
# 27230  2015-03-26        Notre Dame      81            Wichita St.      70
# 27231  2015-03-26         Wisconsin      79         North Carolina      72
# 27232  2015-03-26           Arizona      68                 Xavier      60
# 27233  2015-03-26          Kentucky      78          West Virginia      39
# 27234  2015-03-26        Evansville      89    Louisiana Lafayette      82
# 27235  2015-03-27              Duke      63                   Utah      57
# 27236  2015-03-27      Michigan St.      62               Oklahoma      58
# 27237  2015-03-27        Louisville      75     North Carolina St.      65
# 27238  2015-03-27           Gonzaga      74                   UCLA      62
# 27239  2015-03-27  Northern Arizona      74               Kent St.      73
# 27240  2015-03-28         Wisconsin      85                Arizona      78
# 27241  2015-03-28          Kentucky      68             Notre Dame      66
# 27242  2015-03-28              NJIT      78               Canisius      73
# 27243  2015-03-29              Duke      66                Gonzaga      52
# 27244  2015-03-29      Michigan St.      76             Louisville      70
# 27245  2015-03-30    Loyola Chicago      65       Louisiana Monroe      58
# 27246  2015-03-31          Miami FL      60                 Temple      57
# 27247  2015-03-31          Stanford      67           Old Dominion      60
# 27248  2015-03-31        Evansville      79       Tennessee Martin      66
# 27249  2015-03-31  Northern Arizona      68                   NJIT      61
# 27250  2015-04-01    Loyola Chicago      63       Louisiana Monroe      62
# 27251  2015-04-02          Stanford      66               Miami FL      64
# 27252  2015-04-02        Evansville      71       Northern Arizona      65
# 27253  2015-04-04         Wisconsin      71               Kentucky      64
# 27254  2015-04-04              Duke      81           Michigan St.      61
# 27255  2015-04-06              Duke      68              Wisconsin      63
#
#                  predicted  predicted_score  predicted_score2  \
# 0               Pittsburgh               78                61
# 1                 Illinois               77                57
# 2                 Maryland               91                66
# 3                    Texas               87                60
# 4                 Maryland               86                70
# 5               Pittsburgh               82                59
# 6                    Texas               84                59
# 7                 Illinois               81                49
# 8               Georgetown               64                63
# 9                   Temple               71                65
# 10           Southern Miss               62                60
# 11                    Iona               65                64
# 12               Minnesota               70                61
# 13          Saint Joseph's               71                68
# 14            Missouri St.               71                63
# 15                    UTEP               70                62
# 16            Northeastern               65                63
# 17                   Tulsa               72                66
# 18                Kentucky               76                63
# 19                Syracuse               72                59
# 20               Loyola MD               65                63
# 21           Massachusetts               74                67
# 22               Princeton               62                58
# 23                Canisius               68                66
# 24        UC Santa Barbara               63                59
# 25          Loyola Chicago               69                65
# 26        Florida Atlantic               74                69
# 27                Iowa St.               70                66
# 28            Portland St.               71                70
# 29          North Carolina               86                70
# ...                    ...              ...               ...
# 27226               Temple               70                66
# 27227     Louisiana Monroe               59                58
# 27228     Eastern Kentucky               68                62
# 27229       Loyola Chicago               63                56
# 27230          Wichita St.               69                68
# 27231            Wisconsin               74                68
# 27232              Arizona               74                64
# 27233             Kentucky               74                62
# 27234  Louisiana Lafayette               75                71
# 27235                 Duke               67                66
# 27236             Oklahoma               68                67
# 27237           Louisville               66                63
# 27238              Gonzaga               77                69
# 27239             Kent St.               65                64
# 27240              Arizona               66                65
# 27241             Kentucky               73                64
# 27242                 NJIT               69                66
# 27243                 Duke               75                74
# 27244         Michigan St.               65                64
# 27245       Loyola Chicago               60                55
# 27246             Miami FL               65                64
# 27247             Stanford               63                62
# 27248           Evansville               71                65
# 27249     Northern Arizona               71                68
# 27250     Louisiana Monroe               59                57
# 27251             Stanford               69                68
# 27252           Evansville               72                64
# 27253             Kentucky               65                62
# 27254                 Duke               73                68
# 27255            Wisconsin               70                69
#
#                                 venue          city state        tm  month  \
# 0              Petersen Events Center    Pittsburgh    PA       TBA     11
# 1                       Assembly Hall     Champaign    IL       TBA     11
# 2                      Comcast Center  College Park    MD       TBA     11
# 3      Frank Erwin Special Events Cen        Austin    TX       TBA     11
# 4                      Comcast Center  College Park    MD       TBA     11
# 5              Petersen Events Center    Pittsburgh    PA       TBA     11
# 6      Frank Erwin Special Events Cen        Austin    TX       TBA     11
# 7                       Assembly Hall     Champaign    IL       TBA     11
# 8         Constant Convocation Center       Norfolk    VA       TBA     11
# 9                    Liacouras Center  Philadelphia    PA       TBA     11
# 10                       USF Sun Dome         Tampa    FL       TBA     11
# 11                    Wolstein Center     Cleveland    OH       TBA     11
# 12                     Williams Arena   Minneapolis    MN       TBA     11
# 13         Michael J. Hagan '85 Arena  Philadelphia    PA       TBA     11
# 14                          JQH Arena   Springfield    MO       TBA     11
# 15                 Don Haskins Center       El Paso    TX       TBA     11
# 16                     Matthews Arena        Boston    MA       TBA     11
# 17             Donald Reynolds Center         Tulsa    OK       TBA     11
# 18                         Rupp Arena     Lexington    KY       TBA     11
# 19                       Carrier Dome      Syracuse    NY       TBA     11
# 20                        Reitz Arena     Baltimore    MD       TBA     11
# 21          William D. Mullins Center       Amherst    MA       TBA     11
# 22      L. Stockwell Jadwin Gymnasium     Princeton    NJ       TBA     11
# 23           Koessler Athletic Center       Buffalo    NY       TBA     11
# 24                     McArthur Court        Eugene    OR       TBA     11
# 25           Joseph J. Gentile Center       Chicago    IL       TBA     11
# 26             Earle A. Chiles Center      Portland    OR       TBA     11
# 27           James H. Hilton Coliseum          Ames    IA       TBA     11
# 28               Peter W Stott Center      Portland    OR       TBA     11
# 29               Dean E. Smith Center   Chapel Hill    NC       TBA     11
# ...                               ...           ...   ...       ...    ...
# 27226                Liacouras Center  Philadelphia    PA   9:00 pm      3
# 27227             Fant-Ewing Coliseum        Monroe    LA   8:00 pm      3
# 27228                  McBrayer Arena      Richmond    KY   7:00 pm      3
# 27229        Joseph J. Gentile Center       Chicago    IL   8:00 pm      3
# 27230             Quicken Loans Arena     Cleveland    OH   7:15 pm      3
# 27231                  Staples Center   Los Angeles    CA   7:47 pm      3
# 27232                  Staples Center   Los Angeles    CA  10:17 pm      3
# 27233             Quicken Loans Arena     Cleveland    OH   9:45 pm      3
# 27234               Blackham Coliseum     Lafayette    LA   8:30 pm      3
# 27235                     NRG Stadium       Houston    TX   9:45 pm      3
# 27236                    Carrier Dome      Syracuse    NY  10:07 pm      3
# 27237                    Carrier Dome      Syracuse    NY   7:37 pm      3
# 27238                     NRG Stadium       Houston    TX   7:15 pm      3
# 27239                  Walkup Skydome     Flagstaff    AZ  10:00 pm      3
# 27240                  Staples Center   Los Angeles    CA   6:09 pm      3
# 27241             Quicken Loans Arena     Cleveland    OH   8:49 pm      3
# 27242                 Fleisher Center        Newark    NJ   7:30 pm      3
# 27243                     NRG Stadium       Houston    TX   5:05 pm      3
# 27244                    Carrier Dome      Syracuse    NY   2:20 pm      3
# 27245        Joseph J. Gentile Center       Chicago    IL   8:00 pm      3
# 27246           Madison Square Garden      New York    NY   7:00 pm      3
# 27247           Madison Square Garden      New York    NY   9:00 pm      3
# 27248                     Ford Center    Evansville    IN   7:00 pm      3
# 27249                  Walkup Skydome     Flagstaff    AZ   9:00 pm      3
# 27250             Fant-Ewing Coliseum        Monroe    LA   8:00 pm      4
# 27251           Madison Square Garden      New York    NY   9:00 pm      4
# 27252                     Ford Center    Evansville    IN   7:00 pm      4
# 27253               Lucas Oil Stadium  Indianapolis    IN   8:49 pm      4
# 27254               Lucas Oil Stadium  Indianapolis    IN   6:09 pm      4
# 27255               Lucas Oil Stadium  Indianapolis    IN   9:18 pm      4
#
#       outcome pred_outcome correct
# 0        True         True    True
# 1        True         True    True
# 2        True         True    True
# 3        True         True    True
# 4        True         True    True
# 5        True         True    True
# 6        True         True    True
# 7        True         True    True
# 8        True         True    True
# 9        True         True    True
# 10       True         True    True
# 11       True         True   False
# 12       True         True    True
# 13       True         True   False
# 14       True         True    True
# 15       True         True   False
# 16       True         True    True
# 17       True         True   False
# 18       True         True    True
# 19       True         True    True
# 20       True         True   False
# 21       True         True    True
# 22       True         True    True
# 23       True         True    True
# 24       True         True    True
# 25       True         True    True
# 26       True         True    True
# 27       True         True    True
# 28       True         True    True
# 29       True         True    True
# ...       ...          ...     ...
# 27226    True         True    True
# 27227    True         True    True
# 27228    True         True   False
# 27229    True         True    True
# 27230    True         True   False
# 27231    True         True    True
# 27232    True         True    True
# 27233    True         True    True
# 27234    True         True   False
# 27235    True         True    True
# 27236    True         True   False
# 27237    True         True    True
# 27238    True         True    True
# 27239    True         True   False
# 27240    True         True   False
# 27241    True         True    True
# 27242    True         True    True
# 27243    True         True    True
# 27244    True         True    True
# 27245    True         True    True
# 27246    True         True    True
# 27247    True         True    True
# 27248    True         True    True
# 27249    True         True    True
# 27250    True         True   False
# 27251    True         True    True
# 27252    True         True    True
# 27253    True         True   False
# 27254    True         True    True
# 27255    True         True   False
#
# [27256 rows x 16 columns]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score

lr = LogisticRegression()
rf = RandomForestClassifier(max_depth=5)
X = df0[['hortg', 'aortg', 'hdrtg', 'adrtg']].values
y = df0['home_outcome'].values
cvs = cross_val_score(lr, X, y, cv=10)

# %%
cvs, np.mean(cvs)
# Out:
# (array([ 0.72813239,  0.78486998,  0.70685579,  0.69030733,  0.68646081,
#          0.71971496,  0.6888361 ,  0.70783848,  0.72209026,  0.71021378]),
#  0.71453198789328565)
